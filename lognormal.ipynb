# %%
import pandas as pd
import numpy as np
import seaborn as sn

# %%
inc = pd.read_csv("income1.csv")

# %%
inc = pd.read_csv("income1.csv",names=["income","count"], skiprows=1)

# %%
inc
# Out:
#     income  count
# 0     5000   4371
# 1    10000   3295
# 2    15000   5825
# 3    20000   6047
# 4    25000   6097
# 5    30000   5738
# 6    35000   6100
# 7    40000   5720
# 8    45000   5098
# 9    50000   4991
# 10   55000   5152
# 11   60000   4194
# 12   65000   4411
# 13   70000   3709
# 14   75000   3811
# 15   80000   3766
# 16   85000   3565
# 17   90000   3035
# 18   95000   2753
# 19  100000   2644
# 20  105000   2692
# 21  110000   2180
# 22  115000   2278
# 23  120000   1932
# 24  125000   1992
# 25  130000   1656
# 26  135000   1547
# 27  140000   1424
# 28  145000   1342
# 29  150000   1134
# 30  155000   1489
# 31  160000   1006
# 32  165000   1085
# 33  170000    784
# 34  175000    869
# 35  180000    849
# 36  185000    730
# 37  190000    688
# 38  195000    697
# 39  200000    508

# %%
g = sn.barplot(x="income", y="count", data=inc);
g.set_xticklabels(g.get_xticklabels(), 
                  rotation=90,
                 horizontalalignment="right")
# Out:
# [Text(0, 0, '5000'),
#  Text(1, 0, '10000'),
#  Text(2, 0, '15000'),
#  Text(3, 0, '20000'),
#  Text(4, 0, '25000'),
#  Text(5, 0, '30000'),
#  Text(6, 0, '35000'),
#  Text(7, 0, '40000'),
#  Text(8, 0, '45000'),
#  Text(9, 0, '50000'),
#  Text(10, 0, '55000'),
#  Text(11, 0, '60000'),
#  Text(12, 0, '65000'),
#  Text(13, 0, '70000'),
#  Text(14, 0, '75000'),
#  Text(15, 0, '80000'),
#  Text(16, 0, '85000'),
#  Text(17, 0, '90000'),
#  Text(18, 0, '95000'),
#  Text(19, 0, '100000'),
#  Text(20, 0, '105000'),
#  Text(21, 0, '110000'),
#  Text(22, 0, '115000'),
#  Text(23, 0, '120000'),
#  Text(24, 0, '125000'),
#  Text(25, 0, '130000'),
#  Text(26, 0, '135000'),
#  Text(27, 0, '140000'),
#  Text(28, 0, '145000'),
#  Text(29, 0, '150000'),
#  Text(30, 0, '155000'),
#  Text(31, 0, '160000'),
#  Text(32, 0, '165000'),
#  Text(33, 0, '170000'),
#  Text(34, 0, '175000'),
#  Text(35, 0, '180000'),
#  Text(36, 0, '185000'),
#  Text(37, 0, '190000'),
#  Text(38, 0, '195000'),
# ...

# %%
g = sn.barplot(x="income", y="count", data=inc)
g.set_xticklabels(g.get_xticklabels(), 
                  rotation=90,
                 horizontalalignment="right")
g.set(xscale="log")
# Out:
# [None]
