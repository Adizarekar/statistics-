# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("F:/Education/DS_Roadmap/py-master/ML/1_linear_reg/Exercise/canada_per_capita_income.csv")

# %%
df
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
plt.scatter(df.year,df.per capita income (US$))
# Out:
#   File "C:\Users\Aditya Zarekar\AppData\Local\Temp\ipykernel_2192\2959822253.py", line 1
#     plt.scatter(df.year,df.per capita income (US$))
#                                ^
# SyntaxError: invalid syntax

# %%
df = pd.read_csv("F:/Education/DS_Roadmap/py-master/ML/1_linear_reg/Exercise/canada_per_capita_income.csv",
                 names=["year","income"], skiprows=1)

# %%
df
# Out:
#     year        income
# 0   1970   3399.299037
# 1   1971   3768.297935
# 2   1972   4251.175484
# 3   1973   4804.463248
# 4   1974   5576.514583
# 5   1975   5998.144346
# 6   1976   7062.131392
# 7   1977   7100.126170
# 8   1978   7247.967035
# 9   1979   7602.912681
# 10  1980   8355.968120
# 11  1981   9434.390652
# 12  1982   9619.438377
# 13  1983  10416.536590
# 14  1984  10790.328720
# 15  1985  11018.955850
# 16  1986  11482.891530
# 17  1987  12974.806620
# 18  1988  15080.283450
# 19  1989  16426.725480
# 20  1990  16838.673200
# 21  1991  17266.097690
# 22  1992  16412.083090
# 23  1993  15875.586730
# 24  1994  15755.820270
# 25  1995  16369.317250
# 26  1996  16699.826680
# 27  1997  17310.757750
# 28  1998  16622.671870
# 29  1999  17581.024140
# 30  2000  18987.382410
# 31  2001  18601.397240
# 32  2002  19232.175560
# 33  2003  22739.426280
# 34  2004  25719.147150
# 35  2005  29198.055690
# 36  2006  32738.262900
# 37  2007  36144.481220
# 38  2008  37446.486090
# ...

# %%
plt.scatter(df.year, df.income, marker="+", color="red")
plt.xlabel("Year")
plt.ylabel("per capita Income(US$)")
# Out:
# Text(0, 0.5, 'per capita Income(US$)')

# %%
reg =LinearRegression()

# %%
x=df[["year"]].values

# %%
y=df.income

# %%
y.values
# Out:
# array([ 3399.299037,  3768.297935,  4251.175484,  4804.463248,
#         5576.514583,  5998.144346,  7062.131392,  7100.12617 ,
#         7247.967035,  7602.912681,  8355.96812 ,  9434.390652,
#         9619.438377, 10416.53659 , 10790.32872 , 11018.95585 ,
#        11482.89153 , 12974.80662 , 15080.28345 , 16426.72548 ,
#        16838.6732  , 17266.09769 , 16412.08309 , 15875.58673 ,
#        15755.82027 , 16369.31725 , 16699.82668 , 17310.75775 ,
#        16622.67187 , 17581.02414 , 18987.38241 , 18601.39724 ,
#        19232.17556 , 22739.42628 , 25719.14715 , 29198.05569 ,
#        32738.2629  , 36144.48122 , 37446.48609 , 32755.17682 ,
#        38420.52289 , 42334.71121 , 42665.25597 , 42676.46837 ,
#        41039.8936  , 35175.18898 , 34229.19363 ])

# %%
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
reg.predict([[2020]])
# Out:
# array([41288.69409442])

# %%
reg.coef_
# Out:
# array([828.46507522])

# %%
reg.intercept_
# Out:
# -1632210.7578554575
