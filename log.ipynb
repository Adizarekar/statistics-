# %%
import numpy as np
import pandas as pd
import seaborn as sn

# %%
rev = pd.read_csv("revenue.csv")

# %%
rev
# Out:
#          company  revenue
# 0         Tesla      31.0
# 1           UBER     11.0
# 2         Amazon    386.0
# 3  Jindal  Steel      4.7
# 4      Axis Bank      5.6
# 5        Vedanta     11.3

# %%
rev.plot()
# Out:
# <AxesSubplot:>

# %%
rev.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
rev.plot(x="company", y="revenue",kind="bar")
# Out:
# <AxesSubplot:xlabel='company'>

# %%
rev.plot(x="company", y="revenue",kind="bar", logy=True)
# Out:
# <AxesSubplot:xlabel='company'>
